# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#21bai1027
df=pd.read_csv('C:/Users/nihar/Downloads/may13thdata.csv')
df
# Out:
#        Unnamed: 0  ride.alc.driver  female  grade  age4  smoke  DriverLicense  \
# 0               1                1     1.0   10.0  15.0    1.0            0.0
# 1               2                1     1.0   10.0  18.0    1.0            1.0
# 2               3                1     NaN    NaN   NaN    NaN            NaN
# 3               4                0     0.0   11.0  17.0    0.0            1.0
# 4               5                0     0.0   11.0  17.0    0.0            1.0
# ...           ...              ...     ...    ...   ...    ...            ...
# 13382       13383                0     NaN    9.0  15.0    0.0            0.0
# 13383       13384                0     NaN    9.0  15.0    0.0            0.0
# 13384       13385                0     NaN    9.0  15.0    0.0            0.0
# 13385       13386                0     NaN    9.0  15.0    0.0            0.0
# 13386       13387                0     NaN    9.0  15.0    0.0            0.0
#
#        In_Month
# ...

# %%
#21bai1027
df1=df.drop('Unnamed: 0',axis=1)
df1
# Out:
#        ride.alc.driver  female  grade  age4  smoke  DriverLicense  In_Month
# 0                    1     1.0   10.0  15.0    1.0            0.0   39343.0
# 1                    1     1.0   10.0  18.0    1.0            1.0   46205.0
# 2                    1     NaN    NaN   NaN    NaN            NaN       NaN
# 3                    0     0.0   11.0  17.0    0.0            1.0   43525.0
# 4                    0     0.0   11.0  17.0    0.0            1.0   39891.0
# ...                ...     ...    ...   ...    ...            ...       ...
# 13382                0     NaN    9.0  15.0    0.0            0.0  216303.0
# 13383                0     NaN    9.0  15.0    0.0            0.0  216379.0
# 13384                0     NaN    9.0  15.0    0.0            0.0  216455.0
# 13385                0     NaN    9.0  15.0    0.0            0.0  216530.0
# 13386                0     NaN    9.0  15.0    0.0            0.0  216606.0
#
# [13387 rows x 7 columns]

# %%
#21bai1027
df2=df1.rename(columns={'ride.alc.driver':'drunken','age4':'age','smoke':'smoked','DriverLicense':'driver_license','In_Month':'Income'})
df2
# Out:
#        drunken  female  grade   age  smoked  driver_license    Income
# 0            1     1.0   10.0  15.0     1.0             0.0   39343.0
# 1            1     1.0   10.0  18.0     1.0             1.0   46205.0
# 2            1     NaN    NaN   NaN     NaN             NaN       NaN
# 3            0     0.0   11.0  17.0     0.0             1.0   43525.0
# 4            0     0.0   11.0  17.0     0.0             1.0   39891.0
# ...        ...     ...    ...   ...     ...             ...       ...
# 13382        0     NaN    9.0  15.0     0.0             0.0  216303.0
# 13383        0     NaN    9.0  15.0     0.0             0.0  216379.0
# 13384        0     NaN    9.0  15.0     0.0             0.0  216455.0
# 13385        0     NaN    9.0  15.0     0.0             0.0  216530.0
# 13386        0     NaN    9.0  15.0     0.0             0.0  216606.0
#
# [13387 rows x 7 columns]

# %%
#21bai1027
mean_r = lambda df2: df2.fillna(df2.mean())
cols1=['Income','age']
df2 = df2.groupby(cols1).transform(mean_r)
mode_r=lambda df2: df2.fillna(df2.mode())
cols2=['smoked','drunken','driving_license']
df2 = df2.groupby(cols1).transform(mode_r)
df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 7
#       5 mode_r=lambda df2: df2.fillna(df2.mode())
#       6 cols2=['smoked','drunken','driving_license']
# ----> 7 df2 = df2.groupby(cols1).transform(mode_r)
#       8 df2
#
# File D:\Anaconda\lib\site-packages\pandas\core\frame.py:8402, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8399     raise TypeError("You have to supply one of 'by' and 'level'")
#    8400 axis = self._get_axis_number(axis)
# -> 8402 return DataFrameGroupBy(
#    8403     obj=self,
#    8404     keys=by,
#    8405     axis=axis,
#    8406     level=level,
#    8407     as_index=as_index,
#    8408     sort=sort,
#    8409     group_keys=group_keys,
#    8410     squeeze=squeeze,
#    8411     observed=observed,
#    8412     dropna=dropna,
#    8413 )
#
# ...

# %% [markdown]
# df2['drunken'].plot.bar(ax=ax,label='Yes/No', width=0.8)

# %%
values=df['Income'].max()
x=df['Income'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Anaconda\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 6
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2['driver_license'].plot.bar(X='driving_license',label='YEs\ No', width=0.8)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df2['driver_license'].plot.bar(X='driving_license',label='YEs\ No', width=0.8)
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_core.py:1159, in PlotAccessor.bar(self, x, y, **kwargs)
#    1071 @Appender(
#    1072     """
#    1073     See Also
#    (...)
#    1148 @Appender(_bar_or_line_doc)
#    1149 def bar(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1150     """
#    1151     Vertical bar plot.
#    1152
#    (...)
#    1157     other axis represents a measured value.
#    1158     """
# -> 1159     return self(kind="bar", x=x, y=y, **kwargs)
#
# File D:\Anaconda\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# ...

# %%
#21BAI1027
ax = df2.plot.scatter(x='age', y='drunken',figsize=(10,20))

# %%
#21BAI1027

df2['IncomeV1']=df2['Income']/df2['Income'].max()
